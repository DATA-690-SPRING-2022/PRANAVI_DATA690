# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranavigadikoppula/PRANAVI_DATA690/blob/main/Individual_project/project_partb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Education and its impact on other factors like employment and economic growth.
#
#
#   Education is  the acquisition of knowledged and personal development. Education is  helpful in transmission of cultural heritage from one generation to the next. education provides us lot of information and creates a platform for liberation of ideas.In this project we are going to analyze what is the education ratio between different countries of diferent region.The motive of this project is to analyze what is the ration and how it impacts other factors such as social development as we go on we get to understand what differenece that it makes without education and also how people are moving towards to gain education from the years 2010-2018.Here in this i have just considered few indicators there are many other indicators which are clearly showing that how education is considered in both countries and the result of no-education.

# %%
import pandas as pd
import plotly
import plotly.express as px

DATA_URL = "https://raw.githubusercontent.com/Pranavigadikoppula/PRANAVI_DATA690/main/wdi_data%20(3).csv"

# %% [markdown]
# ## Analysis Strategy and Approach
#
# Data Source: World Development Explorer
#
# Countries Analyzed: India,Afganisthan,pakisthan,nepal,bangladesh,china,south africa, united states
#
# Timespan of Data: 2010-2018
#
#
# ### Topics & Indicators:
#
#  **topic - Education**
#
#  indicators
#
# 1. percentage of female population age 15-19 with no education:
#
#      - In total population how many female's of age 15-19 having no education.
#
# 2. percentage of population age 15-19 with no education:
#
#      - Total population of age 15-19 without education
#
# 3. school enrollment,primary(gross),gender parity index(gpi):
#
#      - Here, how may children's are enrolling for mrimary school to gender parity index

# %% [markdown]
# **topic:Social Development**
#
# indicators
#
# 1. Labor force participation rate,female:
#
#     - population who works as labours
#
# 2. unemployment in population:
#
#      -  population having no work
#
# ### What am i investigating/exploring/analyzing?:
#
# My analysis is about how countries give importance to education and how education is provided to different parts of the world .Here , in this project i have considered the countries india,afganisthan,pakisthan,nepal,bangladesh,china the southern part of Asia and the north part of america and the south part of africa .So, here I have considered all the parts of world countries with heavy population and also countries with less population.
#
# ### Why is it important to me and others?
#
# If we get to analysis all these we can get the solutions to the question which countries are giving importance to education and what are the impacts of not having education .which part of the world has been developed.Here in this analysis i have taken both dveloped countries and developing countries .so we can summarize of all this things.

# %% [markdown]
# ### What answers i am going to get to my questions.
#
# In this analysis ,My questions are what is the difference between the education provided in the developed countries and developing countries.What are the factors effecting them about providing education.In additional to these question is that really employment is related to education.
#
# ### What step am i using to analyze the situation.
#
# In this analysis, I have taken the bar graphs,pie charts so that i can compare the proportions of how the countries are giving the importance and taken the indicators like total population having no education at secondary level, Females having education and the primary school enrollments. On the other hand, i have taken the indicators countries having unemployment in total population and labor force participation of females.

# %%
df = pd.read_csv(DATA_URL)#reads the file

df.sample(10)
# Out:
#     Unnamed: 0  Year     value            indicator Country Code  \
# 58          58  2014   0.96124    SE.ENR.PRIM.FM.ZS          ZAF
# 74          74  2010  59.15000  BAR.NOED.15UP.FE.ZS          PAK
# 9            9  2011   0.71258    SE.ENR.PRIM.FM.ZS          AFG
# 68          68  2018   0.99884    SE.ENR.PRIM.FM.ZS          USA
# 45          45  2010   0.85318    SE.ENR.PRIM.FM.ZS          PAK
# 70          70  2010  35.18000  BAR.NOED.15UP.FE.ZS          BGD
# 39          39  2012   1.08791    SE.ENR.PRIM.FM.ZS          NPL
# 73          73  2010  48.03000  BAR.NOED.15UP.FE.ZS          NPL
# 76          76  2010   0.35000  BAR.NOED.15UP.FE.ZS          USA
# 32          32  2013   1.11811    SE.ENR.PRIM.FM.ZS          IND
#
#      Country Name               Region         Income Group    Lending Type
# 58   South Africa  Sub-Saharan Africa   Upper middle income            IBRD
# 74       Pakistan           South Asia  Lower middle income           Blend
# 9     Afghanistan           South Asia           Low income             IDA
# 68  United States        North America          High income  Not classified
# 45       Pakistan           South Asia  Lower middle income           Blend
# 70     Bangladesh           South Asia  Lower middle income             IDA
# 39          Nepal           South Asia  Lower middle income             IDA
# 73          Nepal           South Asia  Lower middle income             IDA
# 76  United States        North America          High income  Not classified
# 32          India           South Asia  Lower middle income            IBRD

# %%
df_2020_pop = df.query("Year == 2010").query("indicator == 'BAR.NOED.1519.ZS'")
df_2020_pop.sample(5)
# Out:
#    Unnamed: 0  Year  value         indicator Country Code  Country Name  \
# 0           0  2010  37.20  BAR.NOED.1519.ZS          AFG   Afghanistan
# 6           6  2010   0.38  BAR.NOED.1519.ZS          ZAF  South Africa
# 5           5  2010  28.33  BAR.NOED.1519.ZS          PAK      Pakistan
# 1           1  2010   0.10  BAR.NOED.1519.ZS          BGD    Bangladesh
# 4           4  2010   5.29  BAR.NOED.1519.ZS          NPL         Nepal
#
#                 Region         Income Group Lending Type
# 0           South Asia           Low income          IDA
# 6  Sub-Saharan Africa   Upper middle income         IBRD
# 5           South Asia  Lower middle income        Blend
# 1           South Asia  Lower middle income          IDA
# 4           South Asia  Lower middle income          IDA

# %%
df_2020_pop_sort = df_2020_pop.sort_values(by="value", ascending=False)

df_2020_pop_sort.head()
# Out:
#    Unnamed: 0  Year  value         indicator Country Code Country Name  \
# 0           0  2010  37.20  BAR.NOED.1519.ZS          AFG  Afghanistan
# 5           5  2010  28.33  BAR.NOED.1519.ZS          PAK     Pakistan
# 3           3  2010   8.13  BAR.NOED.1519.ZS          IND        India
# 4           4  2010   5.29  BAR.NOED.1519.ZS          NPL        Nepal
# 2           2  2010   0.47  BAR.NOED.1519.ZS          CHN        China
#
#                 Region         Income Group Lending Type
# 0           South Asia           Low income          IDA
# 5           South Asia  Lower middle income        Blend
# 3           South Asia  Lower middle income         IBRD
# 4           South Asia  Lower middle income          IDA
# 2  East Asia & Pacific  Upper middle income         IBRD

# %%
fig = px.bar(
    df_2020_pop_sort, 
    x="Country Name", labels={"value":"2010 Population Barro-Lee:Percentage of population age 15-19 with no education", "Country Name":"Country Name"},
    y="value",
     template="plotly_dark",
    color="Country Name",
    height=800,
    
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ef109331-aaac-447f-8993-26a05b63e655" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef109331-aaac-447f-8993-26a05b63e655")) {                    Plotly.newPlot(                        "ef109331-aaac-447f-8993-26a05b63e655",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Population Barro-Lee:Percentage of population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Afghanistan"],"xaxis":"x","y":[37.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Population Barro-Lee:Percentage of population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Pakistan"],"xaxis":"x","y":[28.33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Population Barro-Lee:Percentage of population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[8.13],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Population Barro-Lee:Percentage of population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"Nepal","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Nepal","offsetgroup":"Nepal","orientation":"v","showlegend":true,"textposition":"auto","x":["Nepal"],"xaxis":"x","y":[5.29],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Population Barro-Lee:Percentage of population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[0.47],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Population Barro-Lee:Percentage of population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"South Africa","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Africa","offsetgroup":"South Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["South Africa"],"xaxis":"x","y":[0.38],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Population Barro-Lee:Percentage of population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[0.17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2010 Population Barro-Lee:Percentage of population age 15-19 with no education=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Bangladesh"],"xaxis":"x","y":[0.1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"typ ...

# %% [markdown]
# Here in the bar graph we get to see 8 different countries having percantage of population age 15-19 no education . Among the 8 countries afghanisthan,pakisthan has the low literacy where as bangladesh has good no of percentage of people having education

# %%
df_2020_pop1 = df.query("Year == 2010").query("indicator == 'BAR.NOED.15UP.FE.ZS'")
df_2020_pop.sample(5)
fig = px.pie(
    df_2020_pop1, 
    values='value', names='Country Name',
     template="plotly_dark",
    title='2010 Barro-lee:Percentage of female population age 15+ with no education'

)
fig.update_traces(textposition='inside', textinfo='percent+label')



fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fe235d55-d3c6-4c9e-b89f-5e42d6e2115b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe235d55-d3c6-4c9e-b89f-5e42d6e2115b")) {                    Plotly.newPlot(                        "fe235d55-d3c6-4c9e-b89f-5e42d6e2115b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Country Name=%{label}<br>value=%{value}<extra></extra>","labels":["Afghanistan","Bangladesh","China","India","Nepal","Pakistan","South Africa","United States"],"legendgroup":"","name":"","showlegend":true,"values":[78.24,35.18,7.9,47.22,48.03,59.15,6.68,0.35],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"tic ...

# %% [markdown]
# In the pie chartwe can see female population having age 15+has no education even in female population having no education the afghanisthan stand in the first place where as here  the bangladesh has low amount of female having education.china has more female education when compared to other education

# %%
df_2020_pop2= df.query("indicator == 'SE.ENR.PRIM.FM.ZS'")
df_2020_pop.sample(5)
fig = px.line(
    df_2020_pop2, 
    x="Year", y="value",color="Country Name",
    template="plotly_dark",
    labels={"value":"School enrollment,primary(gross),gender parity index(GPI)"}

     

)



fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="004f997f-bd75-46cb-9134-1465899d1736" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("004f997f-bd75-46cb-9134-1465899d1736")) {                    Plotly.newPlot(                        "004f997f-bd75-46cb-9134-1465899d1736",                        [{"hovertemplate":"Country Name=Afghanistan<br>Year=%{x}<br>School enrollment,primary(gross),gender parity index(GPI)=%{y}<extra></extra>","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[0.6798099875,0.7125800252000001,0.7202600241,0.7028599977000001,0.6982499957,0.6808099747,0.6793699861,0.6761699915,0.6669099927000001],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Bangladesh<br>Year=%{x}<br>School enrollment,primary(gross),gender parity index(GPI)=%{y}<extra></extra>","legendgroup":"Bangladesh","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bangladesh","orientation":"v","showlegend":true,"x":[2010,2017,2018],"xaxis":"x","y":[1.0625100136,1.0717600584,1.0747100115],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=China<br>Year=%{x}<br>School enrollment,primary(gross),gender parity index(GPI)=%{y}<extra></extra>","legendgroup":"China","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[0.9826800227,0.984860003,0.9889000058,0.997609973,1.0007200241,1.0024600029,1.0050899982,1.0094799995,1.0113500357],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=India<br>Year=%{x}<br>School enrollment,primary(gross),gender parity index(GPI)=%{y}<extra></extra>","legendgroup":"India","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[1.0279699564,1.0352499485,1.0388300419,1.1181099415,1.113929987,1.1161799431,1.1610399485,1.1472500563],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Nepal<br>Year=%{x}<br>School enrollment,primary(gross),gender parity index(GPI)=%{y}<extra></extra>","legendgroup":"Nepal","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Nepal","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[1.0761699677,1.0815800428,1.0879100561,1.0820300579,1.0738099813,1.0618100166,1.0518200397,1.0181200504],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Pakistan<br>Year=%{x}<br>School enrollment,primary(gross),gender parity index(GPI)=%{y}<extra></extra>","legendgroup":"Pakistan","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Pakistan","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[0.8531799912,0.8595100045,0.8716499805,0.8697000146,0.8535000086000001,0.8559299707,0.8539800048,0.8630099893000001,0.8444100022000001],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=South Africa<br>Year=%{x}<br>School enrollment,primary(gross),gender parity index(GPI)=%{y}<extra></extra>","legendgroup":"South Africa","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"South Africa","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[0.9617099762,0.9595500231,0.9582399726,0.9578300118,0.9612399936,0.9333800077,0.9680399895,0.9666699 ...

# %% [markdown]
# Here,Afghanisthan has the low school enrollment,gender parity index.India has increaded in primary school enrollment over the years.Bangladesh maintained the same.south africa maintained the stability and got little fluctuation in the year 2015.Nepal has becoming lower in primary school enrollment.

# %%
import pandas as pd
import plotly
import plotly.express as px

DATA_URL1 = "https://raw.githubusercontent.com/Pranavigadikoppula/PRANAVI_DATA690/main/wdi_data%20(6).csv"

# %%
df1 = pd.read_csv(DATA_URL1)

df1.sample(10)
# Out:
#     Unnamed: 0  Year  value          indicator Country Code   Country Name  \
# 79          79  2018  67.23  SL.TLF.ACTI.FE.ZS          USA  United States
# 74          74  2013  66.02  SL.TLF.ACTI.FE.ZS          USA  United States
# 72          72  2011  66.56  SL.TLF.ACTI.FE.ZS          USA  United States
# 61          61  2018  22.62  SL.TLF.ACTI.FE.ZS          PAK       Pakistan
# 11          11  2013  17.42  SL.TLF.ACTI.FE.ZS          AFG    Afghanistan
# 58          58  2015  25.09  SL.TLF.ACTI.FE.ZS          PAK       Pakistan
# 27          27  2011  69.60  SL.TLF.ACTI.FE.ZS          CHN          China
# 73          73  2012  66.52  SL.TLF.ACTI.FE.ZS          USA  United States
# 12          12  2014  18.46  SL.TLF.ACTI.FE.ZS          AFG    Afghanistan
# 60          60  2017  23.42  SL.TLF.ACTI.FE.ZS          PAK       Pakistan
#
#                  Region         Income Group    Lending Type
# 79        North America          High income  Not classified
# 74        North America          High income  Not classified
# 72        North America          High income  Not classified
# 61           South Asia  Lower middle income           Blend
# 11           South Asia           Low income             IDA
# 58           South Asia  Lower middle income           Blend
# 27  East Asia & Pacific  Upper middle income            IBRD
# 73        North America          High income  Not classified
# 12           South Asia           Low income             IDA
# 60           South Asia  Lower middle income           Blend

# %%
df1_2020_popnxt_pivot = df1.pivot_table(index=["Year", "Country Code", "Country Name", "Region", "Income Group", "Lending Type"], 
                                                    columns="indicator", values="value")
df1_2020_popnxt_pivot.head()
# Out:
# indicator                                                                            BAR.NOED.15UP.FE.ZS  \
# Year Country Code Country Name Region              Income Group        Lending Type
# 2010 AFG          Afghanistan  South Asia          Low income          IDA                         78.24
#      BGD          Bangladesh   South Asia          Lower middle income IDA                         35.18
#      CHN          China        East Asia & Pacific Upper middle income IBRD                         7.90
#      IND          India        South Asia          Lower middle income IBRD                        47.22
#      NPL          Nepal        South Asia          Lower middle income IDA                         48.03
#
# indicator                                                                            SL.TLF.ACTI.FE.ZS
# Year Country Code Country Name Region              Income Group        Lending Type
# 2010 AFG          Afghanistan  South Asia          Low income          IDA                       15.65
#      BGD          Bangladesh   South Asia          Lower middle income IDA                       31.10
#      CHN          China        East Asia & Pacific Upper middle income IBRD                      69.75
#      IND          India        South Asia          Lower middle income IBRD                      27.14
#      NPL          Nepal        South Asia          Lower middle income IDA                       82.32

# %%
print(df1_2020_popnxt_pivot .columns.tolist())
# Out:
# ['level_0', 'index', 'Year', 'Country Code', 'Country Name', 'Region', 'Income Group', 'Lending Type', 'BAR.NOED.15UP.FE.ZS', 'SL.TLF.ACTI.FE.ZS']

# %%
df_scatter =df1_2020_popnxt_pivot[df1_2020_popnxt_pivot["Country Code"].isin(["AFG","BGD","CHN","IND","NPL","PAK","USA","ZAF"])].query("Year == 2018")

fig = px.scatter(df1_2020_popnxt_pivot, 
                 x="BAR.NOED.15UP.FE.ZS", 
                 y="SL.TLF.ACTI.FE.ZS",
                 size="SL.TLF.ACTI.FE.ZS",
                 color="Country Name",
                
                 
                 
                 template="plotly_dark",
                 
                
                 labels={"SL.TLF.ACTI.FE.ZS":"2010 Labor force participation rate,female(% of female population ages(15-64)","BAR.NOED.15UP.FE.ZS":"2010:Barro-lee:Percentage of female populationage 15+ with no education"},
                 
                 
                )


fig.update_traces(textposition='top center')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0698ee6c-1ca2-43a6-8d0d-30572e713448" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0698ee6c-1ca2-43a6-8d0d-30572e713448")) {                    Plotly.newPlot(                        "0698ee6c-1ca2-43a6-8d0d-30572e713448",                        [{"hovertemplate":"Country Name=Afghanistan<br>2010:Barro-lee:Percentage of female populationage 15+ with no education=%{x}<br>2010 Labor force participation rate,female(% of female population ages(15-64)=%{marker.size}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[15.65,16.0,16.44,17.42,18.46,19.55,20.7,21.91,22.32],"sizemode":"area","sizeref":0.21267499999999998,"symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[78.24,null,null,null,null,null,null,null,null],"xaxis":"x","y":[15.65,16.0,16.44,17.42,18.46,19.55,20.7,21.91,22.32],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country Name=Bangladesh<br>2010:Barro-lee:Percentage of female populationage 15+ with no education=%{x}<br>2010 Labor force participation rate,female(% of female population ages(15-64)=%{marker.size}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#EF553B","size":[31.1,31.68,32.26,32.84,33.43,34.01,34.59,37.95,38.25],"sizemode":"area","sizeref":0.21267499999999998,"symbol":"circle"},"mode":"markers","name":"Bangladesh","orientation":"v","showlegend":true,"x":[35.18,null,null,null,null,null,null,null,null],"xaxis":"x","y":[31.1,31.68,32.26,32.84,33.43,34.01,34.59,37.95,38.25],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country Name=China<br>2010:Barro-lee:Percentage of female populationage 15+ with no education=%{x}<br>2010 Labor force participation rate,female(% of female population ages(15-64)=%{marker.size}<extra></extra>","legendgroup":"China","marker":{"color":"#00cc96","size":[69.75,69.6,69.47,69.36,69.24,69.14,69.05,68.93,68.78],"sizemode":"area","sizeref":0.21267499999999998,"symbol":"circle"},"mode":"markers","name":"China","orientation":"v","showlegend":true,"x":[7.9,null,null,null,null,null,null,null,null],"xaxis":"x","y":[69.75,69.6,69.47,69.36,69.24,69.14,69.05,68.93,68.78],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country Name=India<br>2010:Barro-lee:Percentage of female populationage 15+ with no education=%{x}<br>2010 Labor force participation rate,female(% of female population ages(15-64)=%{marker.size}<extra></extra>","legendgroup":"India","marker":{"color":"#ab63fa","size":[27.14,25.67,24.26,23.85,23.46,23.1,22.77,22.45,22.16],"sizemode":"area","sizeref":0.21267499999999998,"symbol":"circle"},"mode":"markers","name":"India","orientation":"v","showlegend":true,"x":[47.22,null,null,null,null,null,null,null,null],"xaxis":"x","y":[27.14,25.67,24.26,23.85,23.46,23.1,22.77,22.45,22.16],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country Name=Nepal<br>2010:Barro-lee:Percentage of female populationage 15+ with no education=%{x}<br>2010 Labor force participation rate,female(% of female population ages(15-64)=%{marker.size}<extra></extra>","legendgroup":"Nepal","marker":{"color":"#FFA15A","size":[82.32,82.45,82.72,83.09,83.48,83.84,84.34,84.75,85.07],"sizemode":"area","sizeref":0.21267499999999998,"symbol":"circle"},"mode":"markers","name":"Nepal","orientation":"v","showlegend":true,"x":[48.03,null,null,null,null,null,null,null,null],"xaxis":"x","y":[82.32,82.45,82.72,83.09,83.48,83.84,84.34,84.75,85.07],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country Name=Pakistan<br>2010:Barro-lee:Percentage of female populationage 15+ with no education=%{x}<br>2010 Labor for ...

# %%
import statsmodels.api as sm

#define response variable
y = df1_2020_popnxt_pivot['BAR.NOED.15UP.FE.ZS']

#define explanatory variable
x = df1_2020_popnxt_pivot[['SL.TLF.ACTI.FE.ZS']]

#add constant to predictor variables
x = sm.add_constant(x)

#fit linear regression model
model = sm.OLS(y, x).fit()

#view model summary
print(model.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     BAR.NOED.15UP.FE.ZS   R-squared:                         nan
# Model:                             OLS   Adj. R-squared:                    nan
# Method:                  Least Squares   F-statistic:                       nan
# Date:                 Sat, 09 Apr 2022   Prob (F-statistic):                nan
# Time:                         23:13:29   Log-Likelihood:                    nan
# No. Observations:                   72   AIC:                               nan
# Df Residuals:                       70   BIC:                               nan
# Df Model:                            1
# Covariance Type:             nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                    nan        nan        nan        nan         nan         nan
# SL.TLF.ACTI.FE.ZS        nan        nan        nan        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                         116.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning:
#
# In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only

# %% [markdown]
# In the scatter plot the x axis represents percentage of female population age 15+ with no education and the y-axis represents labor force participation rate,female of age(15-64)

# %%
fig = px.scatter(df1_2020_popnxt_pivot, 
                 x="BAR.NOED.15UP.FE.ZS", 
                 y="SL.TLF.ACTI.FE.ZS",
                  template="plotly_dark",
                 
                
                 labels={"SL.TLF.ACTI.FE.ZS":"2010 Labor force participation rate,female(% of female population ages(15-64)","BAR.NOED.15UP.FE.ZS":"2010:Barro-lee:Percentage of female populationage 15+ with no education"},
                 trendline="ols"
                 
                )



fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c9d4c34a-21c3-436d-b544-ead113871689" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9d4c34a-21c3-436d-b544-ead113871689")) {                    Plotly.newPlot(                        "c9d4c34a-21c3-436d-b544-ead113871689",                        [{"hovertemplate":"2010:Barro-lee:Percentage of female populationage 15+ with no education=%{x}<br>2010 Labor force participation rate,female(% of female population ages(15-64)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[78.24,35.18,7.9,47.22,48.03,59.15,0.35,6.68,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"xaxis":"x","y":[15.65,31.1,69.75,27.14,82.32,22.81,67.14,48.38,16.0,31.68,69.6,25.67,82.45,23.18,66.56,49.11,16.44,32.26,69.47,24.26,82.72,23.39,66.52,49.59,17.42,32.84,69.36,23.85,83.09,23.62,66.02,50.73,18.46,33.43,69.24,23.46,83.48,24.07,66.0,51.11,19.55,34.01,69.14,23.1,83.84,25.09,65.86,52.6,20.7,34.59,69.05,22.77,84.34,24.24,66.29,52.82,21.91,37.95,68.93,22.45,84.75,23.42,66.94,53.89,22.32,38.25,68.78,22.16,85.07,22.62,67.23,53.85],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>OLS trendline</b><br>SL.TLF.ACTI.FE.ZS = -0.558176 * BAR.NOED.15UP.FE.ZS + 65.2643<br>R<sup>2</sup>=0.392647<br><br>2010:Barro-lee:Percentage of female populationage 15+ with no education=%{x}<br>2010 Labor force participation rate,female(% of female population ages(15-64)=%{y} <b>(trend)</b><extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[0.35,6.68,7.9,35.18,47.22,48.03,59.15,78.24],"xaxis":"x","y":[65.06890434273454,61.53565334821381,60.85467922288754,45.6276512401821,38.907218068929396,38.45509590375376,32.24818420405858,21.592613669240144],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"color ...

# %% [markdown]
# This graph represents the same as scatter plot but it shows in a linear regression format.2010 labor force participation rate,female of age 15-64 and age 15+ female population having no education as we can see they are interlinked.

# %%
import pandas as pd
import plotly
import seaborn as sns
import plotly.express as px

DATA_URL3 = "https://raw.githubusercontent.com/Pranavigadikoppula/PRANAVI_DATA690/main/wdi_data%20(7).csv"

# %%
df3= pd.read_csv(DATA_URL3)

df3.sample(10)
# Out:
#     Unnamed: 0  Year  value            indicator Country Code   Country Name  \
# 21          21  2015  19.55    SL.TLF.ACTI.FE.ZS          AFG    Afghanistan
# 25          25  2010  31.10    SL.TLF.ACTI.FE.ZS          BGD     Bangladesh
# 13          13  2010  59.15  BAR.NOED.15UP.FE.ZS          PAK       Pakistan
# 80          80  2011  66.56    SL.TLF.ACTI.FE.ZS          USA  United States
# 64          64  2013  23.62    SL.TLF.ACTI.FE.ZS          PAK       Pakistan
# 66          66  2015  25.09    SL.TLF.ACTI.FE.ZS          PAK       Pakistan
# 8            8  2010  78.24  BAR.NOED.15UP.FE.ZS          AFG    Afghanistan
# 85          85  2016  66.29    SL.TLF.ACTI.FE.ZS          USA  United States
# 87          87  2018  67.23    SL.TLF.ACTI.FE.ZS          USA  United States
# 68          68  2017  23.42    SL.TLF.ACTI.FE.ZS          PAK       Pakistan
#
#            Region         Income Group    Lending Type
# 21     South Asia           Low income             IDA
# 25     South Asia  Lower middle income             IDA
# 13     South Asia  Lower middle income           Blend
# 80  North America          High income  Not classified
# 64     South Asia  Lower middle income           Blend
# 66     South Asia  Lower middle income           Blend
# 8      South Asia           Low income             IDA
# 85  North America          High income  Not classified
# 87  North America          High income  Not classified
# 68     South Asia  Lower middle income           Blend

# %%
x=df3.query("Year==2010 ")
x
# Out:
#     Unnamed: 0  Year  value            indicator Country Code   Country Name  \
# 0            0  2010  59.18  BAR.NOED.1519.FE.ZS          AFG    Afghanistan
# 1            1  2010   0.09  BAR.NOED.1519.FE.ZS          BGD     Bangladesh
# 2            2  2010   0.49  BAR.NOED.1519.FE.ZS          CHN          China
# 3            3  2010  11.09  BAR.NOED.1519.FE.ZS          IND          India
# 4            4  2010   6.89  BAR.NOED.1519.FE.ZS          NPL          Nepal
# 5            5  2010  35.46  BAR.NOED.1519.FE.ZS          PAK       Pakistan
# 6            6  2010   0.30  BAR.NOED.1519.FE.ZS          ZAF   South Africa
# 7            7  2010   0.19  BAR.NOED.1519.FE.ZS          USA  United States
# 8            8  2010  78.24  BAR.NOED.15UP.FE.ZS          AFG    Afghanistan
# 9            9  2010  35.18  BAR.NOED.15UP.FE.ZS          BGD     Bangladesh
# 10          10  2010   7.90  BAR.NOED.15UP.FE.ZS          CHN          China
# 11          11  2010  47.22  BAR.NOED.15UP.FE.ZS          IND          India
# 12          12  2010  48.03  BAR.NOED.15UP.FE.ZS          NPL          Nepal
# 13          13  2010  59.15  BAR.NOED.15UP.FE.ZS          PAK       Pakistan
# 14          14  2010   6.68  BAR.NOED.15UP.FE.ZS          ZAF   South Africa
# 15          15  2010   0.35  BAR.NOED.15UP.FE.ZS          USA  United States
# 16          16  2010  15.65    SL.TLF.ACTI.FE.ZS          AFG    Afghanistan
# 25          25  2010  31.10    SL.TLF.ACTI.FE.ZS          BGD     Bangladesh
# 34          34  2010  69.75    SL.TLF.ACTI.FE.ZS          CHN          China
# 43          43  2010  27.14    SL.TLF.ACTI.FE.ZS          IND          India
# 52          52  2010  82.32    SL.TLF.ACTI.FE.ZS          NPL          Nepal
# 61          61  2010  22.81    SL.TLF.ACTI.FE.ZS          PAK       Pakistan
# 70          70  2010  48.38    SL.TLF.ACTI.FE.ZS          ZAF   South Africa
# 79          79  2010  67.14    SL.TLF.ACTI.FE.ZS          USA  United States
#
#                  Region         Income Group    Lending Type
# 0            South Asia           Low income             IDA
# 1            South Asia  Lower middle income             IDA
# 2   East Asia & Pacific  Upper middle income            IBRD
# 3            South Asia  Lower middle income            IBRD
# 4            South Asia  Lower middle income             IDA
# 5            South Asia  Lower middle income           Blend
# 6   Sub-Saharan Africa   Upper middle income            IBRD
# 7         North America          High income  Not classified
# 8            South Asia           Low income             IDA
# 9            South Asia  Lower middle income             IDA
# 10  East Asia & Pacific  Upper middle income            IBRD
# 11           South Asia  Lower middle income            IBRD
# 12           South Asia  Lower middle income             IDA
# 13           South Asia  Lower middle income           Blend
# 14  Sub-Saharan Africa   Upper middle income            IBRD
# 15        North America          High income  Not classified
# 16           South Asia           Low income             IDA
# 25           South Asia  Lower middle income             IDA
# 34  East Asia & Pacific  Upper middle income            IBRD
# 43           South Asia  Lower middle income            IBRD
# 52           South Asia  Lower middle income             IDA
# 61           South Asia  Lower middle income           Blend
# 70  Sub-Saharan Africa   Upper middle income            IBRD
# 79        North America          High income  Not classified

# %%
df3_2020_popnxt_pivot = x.pivot_table(index=["Year", "Country Code", "Country Name", "Region", "Income Group", "Lending Type"], 
                                                    columns="indicator", values="value")
#df3_2020_popnxt_pivot.reset_index(inplace=True)
df3_2020_popnxt_pivot.head()
# Out:
# indicator                                                                            BAR.NOED.1519.FE.ZS  \
# Year Country Code Country Name Region              Income Group        Lending Type
# 2010 AFG          Afghanistan  South Asia          Low income          IDA                         59.18
#      BGD          Bangladesh   South Asia          Lower middle income IDA                          0.09
#      CHN          China        East Asia & Pacific Upper middle income IBRD                         0.49
#      IND          India        South Asia          Lower middle income IBRD                        11.09
#      NPL          Nepal        South Asia          Lower middle income IDA                          6.89
#
# indicator                                                                            BAR.NOED.15UP.FE.ZS  \
# Year Country Code Country Name Region              Income Group        Lending Type
# 2010 AFG          Afghanistan  South Asia          Low income          IDA                         78.24
#      BGD          Bangladesh   South Asia          Lower middle income IDA                         35.18
#      CHN          China        East Asia & Pacific Upper middle income IBRD                         7.90
#      IND          India        South Asia          Lower middle income IBRD                        47.22
#      NPL          Nepal        South Asia          Lower middle income IDA                         48.03
#
# indicator                                                                            SL.TLF.ACTI.FE.ZS
# Year Country Code Country Name Region              Income Group        Lending Type
# 2010 AFG          Afghanistan  South Asia          Low income          IDA                       15.65
#      BGD          Bangladesh   South Asia          Lower middle income IDA                       31.10
#      CHN          China        East Asia & Pacific Upper middle income IBRD                      69.75
#      IND          India        South Asia          Lower middle income IBRD                      27.14
#      NPL          Nepal        South Asia          Lower middle income IDA                       82.32

# %%
import plotly.graph_objects as go

indicators=["SL.TLF.ACTI.FE.ZS","BAR.NOED.1519.FE.ZS","BAR.NOED.15UP.FE.ZS"]
fig=px.imshow(df3_2020_popnxt_pivot[indicators].corr(),
              height=700,
              title="Correlation Matrix Heatmap(year 2010)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f1cdafd7-7f39-4aaa-8755-636abc15293c" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1cdafd7-7f39-4aaa-8755-636abc15293c")) {                    Plotly.newPlot(                        "f1cdafd7-7f39-4aaa-8755-636abc15293c",                        [{"coloraxis":"coloraxis","name":"0","x":["SL.TLF.ACTI.FE.ZS","BAR.NOED.1519.FE.ZS","BAR.NOED.15UP.FE.ZS"],"y":["SL.TLF.ACTI.FE.ZS","BAR.NOED.1519.FE.ZS","BAR.NOED.15UP.FE.ZS"],"z":[[1.0,-0.6593233010824027,-0.6266155385902261],[-0.6593233010824027,1.0,0.83621747230425],[-0.6266155385902261,0.83621747230425,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"indicator: %{x}<br>indicator: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{ ...

# %% [markdown]
# # conclusion:
#
# In conclusion, the education and social development are inter linked when compared to the graphs afghanisthan has low literacy rate when it comes to no education of total population and the female poipulation of age 15+ having no education. Though bangladesh has education better it has low female education rate. When considering the primary school enrollment there were many changes united states maintained the stability every where . When coming to employment factors the female unemployment was more in the countries which has low education for females.labor force participation in female china and united states hasgood amount of workers . so the reasons for this can be not knowing the importance of education,The rules associated with the countries, The wealth of the countries and several other factors. The graphs shows which countries has good education among total population,females having education, primary school enrollment and the labor force participation of females and the unemployment of total population
#   \
